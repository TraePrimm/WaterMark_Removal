# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from load import WatermarkDataset

batch_size=5
ds = WatermarkDataset('logos_rendered', WatermarkDataset.CNN_MODE, batch_size=batch_size, scale_im=False)

for idx in range(5):
    images = ds[idx]
    fig, axs = plt.subplots(2, batch_size, figsize=(18, 9))
    for (tax, bax), imnw, im in zip(axs.T, images[0], images[1]):
        im = im.numpy().transpose(1, 2, 0)
        imnw = imnw.numpy().transpose(1, 2, 0)
        tax.imshow(im)
        bax.imshow(imnw)
        # bb is (y1, y2, x1, x2)
        # args for Rectanble are (xy, width, height)
        # ax.add_patch(mpatches.Rectangle((bb[2], bb[0]), bb[3]-bb[2], bb[1]-bb[0], fill=False))
